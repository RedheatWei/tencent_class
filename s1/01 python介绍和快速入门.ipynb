# %% [markdown]
# 1.
# python3
# python
# 这是因为解释器版本，我这里装了多版本
#
# 2.
# shebang   sh-bang
# #!/usr/bin/python  或者  #!/usr/env python
#
# 3.
# 字符编码
# #_*_ coding:utf-8 _*_
#
# 4.
# IDE
# https://www.jetbrains.com/pycharm/download/#section=windows
#
# 5.
# 官方文档：https://docs.python.org/3/
# Google
# Stack Overflow
# python核心编程 第二版
# ![image.png](attachment:image.png)
#
# 6.
# 其他解释器
# pypy
# Jython
# IronPython
